# %% [markdown]
# ### 1. Purpose of this notebook
#
# The purpose of this notebook is to explore the pilot campaign data.T
#
# #### What's the question we want to answer with this notebook?
#
# **Who are our customers or who are our principal customers that most responded to the pilot campaign?**
#
# > Based on the answers we get, we can draw a gereal profile our customers:
# -

# %% [markdown]
# ### 2. Read data

# %% [markdown]
# #### 2.1 Import Python packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns
import numpy as np

import src.data_visualization as dv
import src.eda as eda
from src.paths import DATA

# %matplotlib inline
plt.style.use('bmh')

# %load_ext autoreload
# %autoreload 2

# %%
dtypes = {'ID': str}

df = pd.read_csv(DATA / 'ml_project1_data_pre_processed.csv', dtype=dtypes)

# %% [markdown]
# #### 2.2 Sample data

# %%
df.sample(5)
# Out:
#         ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 1184  9855        1952         PhD         Single  62000.0        0         1
# 241   9940        1958  Graduation       Together  64961.0        0         1
# 2232  9405        1954         PhD        Married  52869.0        1         1
# 803   3483        1958  Graduation        Married  48192.0        0         0
# 1833  9847        1955    2n Cycle        Married  62972.0        0         1
#
#      Dt_Customer  Recency  MntWines      ...        Z_CostContact  Response  \
# 1184  2013-08-25       25       899      ...                    3     False
# 241   2012-12-23       97       382      ...                    3     False
# 2232  2012-10-15       40        84      ...                    3      True
# 803   2013-04-06       76      1039      ...                    3      True
# 1833  2012-08-03       39       313      ...                    3     False
#
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Response',
#        'Z_Revenue_correct', 'Age', 'MntTotal', 'NumTotalPurchases',
#        'AcceptedTotalFirstFiveCmps', 'AcceptedTotalFirstFiveCmpsMorePilot',
#        'TotalYearAfterRegistration', 'TotalChildren'],
#       dtype='object')

# %%
df_accepted_total_first_five_cmps = df.query('AcceptedTotalFirstFiveCmps > 0')
df_accepted_total_first_five_cmps.sample(10).T
# Out:
#                                            723         1733     1469  \
# ID                                         4692       10556     4070
# Education                            Graduation  Graduation      PhD
# Marital_Status                          Married     Married  Married
# Income                                     7500       54984    94871
# Kidhome                                       1           0        0
# Teenhome                                      0           1        2
# Recency                                      19          51       99
# MntWines                                      7         173      169
# MntFruits                                     0          13       24
# MntMeatProducts                              12         131      553
# MntFishProducts                              13          32      188
# MntSweetProducts                              7           3        0
# MntGoldProds                                 32           6      144
# ...

# %%
df_accepted_total_first_five_cmps['MntTotal'].describe()
# Out:
# count     463.000000
# mean     1033.602592
# std       652.495786
# min         8.000000
# 25%       445.000000
# 50%      1080.000000
# 75%      1579.000000
# max      2491.000000
# Name: MntTotal, dtype: float64

# %%
df_not_accepted_total_first_five_cmps = df.query('AcceptedTotalFirstFiveCmps == 0')
df_not_accepted_total_first_five_cmps['MntTotal'].describe()
# Out:
# count    1770.000000
# mean      440.457062
# std       485.287562
# min         6.000000
# 25%        47.000000
# 50%       222.500000
# 75%       777.000000
# max      2262.000000
# Name: MntTotal, dtype: float64

# %%
df_accepted_total_first_five_cmps
# Out:
#          ID   Education Marital_Status    Income  Kidhome  Teenhome  Recency  \
# 9      5899         PhD       Together    5648.0        1         1       68
# 15     2114         PhD         Single   82800.0        0         0       23
# 18     6565      Master        Married   76995.0        0         1       91
# 22     1993         PhD        Married   58607.0        0         1       63
# 29     1966         PhD        Married   84618.0        0         0       96
# 32     5710  Graduation       Together   40548.0        0         1       31
# 39     2968         PhD       Divorced   48948.0        0         0       53
# 53     2225  Graduation       Divorced   82582.0        0         0       54
# 55     6260      Master       Together   82384.0        0         0       55
# 60     6853      Master         Single   75777.0        0         0       12
# 67     9369    2n Cycle         Single   88194.0        0         1       19
# ...

# %%
six_campaign = df.query('Response == 1')
not_six_campaign = df.query('Response == 0')

# %%
six_campaign['Recency'].value_counts(bins=10, sort=False)
# Out:
# (-0.1, 9.9]     70
# (9.9, 19.8]     62
# (19.8, 29.7]    34
# (29.7, 39.6]    37
# (39.6, 49.5]    26
# (49.5, 59.4]    27
# (59.4, 69.3]    24
# (69.3, 79.2]    25
# (79.2, 89.1]    16
# (89.1, 99.0]    13
# Name: Recency, dtype: int64

# %%
six_campaign['NumTotalPurchases'].value_counts(normalize=True).sort_index()
# Out:
# 3     0.017964
# 4     0.041916
# 5     0.044910
# 6     0.056886
# 7     0.053892
# 8     0.026946
# 9     0.002994
# 10    0.011976
# 11    0.029940
# 12    0.032934
# 13    0.023952
# 14    0.053892
# 15    0.065868
# 16    0.053892
# 17    0.047904
# 18    0.077844
# 19    0.059880
# 20    0.041916
# 21    0.068862
# 22    0.056886
# 23    0.014970
# 24    0.032934
# 25    0.023952
# 26    0.014970
# 27    0.020958
# 28    0.008982
# 30    0.002994
# 31    0.002994
# 32    0.005988
# Name: NumTotalPurchases, dtype: float64

# %%
not_six_campaign['NumTotalPurchases'].value_counts(normalize=True).sort_index()
# Out:
# 1     0.002633
# 2     0.001053
# 3     0.064244
# 4     0.098999
# 5     0.086888
# 6     0.090574
# 7     0.057925
# 8     0.022117
# 9     0.023170
# 10    0.026330
# 11    0.035282
# 12    0.027909
# 13    0.035282
# 14    0.043181
# 15    0.032649
# 16    0.042127
# 17    0.038441
# 18    0.041074
# 19    0.034229
# 20    0.037388
# 21    0.033175
# 22    0.029489
# 23    0.031069
# 24    0.021590
# 25    0.016324
# 26    0.010005
# 27    0.008425
# 28    0.003686
# 29    0.003160
# 30    0.000527
# 31    0.000527
# 32    0.000527
# Name: NumTotalPurchases, dtype: float64

# %%
six_campaign.describe().T
# Out:
#                                      count          mean           std  \
# Year_Birth                           334.0   1969.416168     12.398192
# Income                               333.0  60209.675676  23194.080987
# Kidhome                              334.0      0.341317      0.487347
# Teenhome                             334.0      0.305389      0.492741
# Recency                              334.0     35.383234     27.659499
# MntWines                             334.0    502.703593    427.183786
# MntFruits                            334.0     38.203593     46.099519
# MntMeatProducts                      334.0    294.353293    286.890036
# MntFishProducts                      334.0     52.050898     61.855885
# MntSweetProducts                     334.0     38.634731     46.327903
# MntGoldProds                         334.0     61.446108     57.507501
# NumDealsPurchases                    334.0      2.335329      2.109924
# ...

# %%
not_six_campaign.describe().T
# Out:
#                                       count          mean           std  \
# Year_Birth                           1899.0   1968.695629     11.910097
# Income                               1876.0  50851.329957  24953.154987
# Kidhome                              1899.0      0.462875      0.545183
# Teenhome                             1899.0      0.542917      0.545724
# Recency                              1899.0     51.494997     28.536545
# MntWines                             1899.0    270.051080    305.318119
# MntFruits                            1899.0     24.293839     38.239182
# MntMeatProducts                      1899.0    145.117957    205.512166
# MntFishProducts                      1899.0     35.102686     52.928810
# MntSweetProducts                     1899.0     25.119010     40.050121
# MntGoldProds                         1899.0     41.115324     50.611236
# NumDealsPurchases                    1899.0      2.308057      1.832384
# ...
